# %%
# Advanced Seaborn Plot - Pairplot
# Objective: Use Seaborn to create a pairplot to visualize pairwise relationships in a dataset.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load a dataset from Seaborn (example: Iris dataset)
df = sns.load_dataset("iris")

# Create a pairplot
sns.pairplot(df, 
                hue="species",      # Color points by the species column
                diag_kind="kde",    # Use Kernel Density Estimation on the diagonal
                markers=["o", "s", "D"],  # Different markers for different species
                palette="Set2",     # Choose a color palette
                height=2.5,         # Size of each plot
                orner=True)        # Remove the upper triangle of the plot

Show the plot
plt.show()
# Out:
#   Cell In[4], line 16
#     Show the plot
#          ^
# SyntaxError: invalid syntax

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load a dataset from Seaborn (example: Iris dataset)
df = sns.load_dataset("iris")

# Create a pairplot
sns.pairplot(df, 
            hue="species",      # Color points by the species column
            diag_kind="kde",    # Use Kernel Density Estimation on the diagonal
            markers=["o", "s", "D"],  # Different markers for different species
            palette="Set2",     # Choose a color palette
            height=2.5,         # Size of each plot
            corner=True)        # Remove the upper triangle of the plot

# Show the plot
plt.show()  # This line should not have caused an error if correctly formatted
